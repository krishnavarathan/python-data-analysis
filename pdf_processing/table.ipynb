# %%
import tabula

provisinal_pdf = r"Data/DT20234570014_Provisinal Offer Letter.pdf"
hcl_pdf= r"C:\Users\krishna varathan\Documents\PDF_Spitting\Data\Application_form_HCLTFP1880079.pdf"
application_pdf=r"Data/DT20234570014_Application Form.pdf"
payslip_pdf=r"Data/Jan.pdf"
llr_pdf=r"Data/KARUPPU_LLR.pdf"

# %%
import os

print(os.path.exists(application_pdf))
# Out:
# True

# %%
application_pdf = r"C:\Users\krishna varathan\Documents\PDF_Spitting\Data\DT20234570014_Application_Form.pdf"

application_pdf
# Out:
# 'C:\\Users\\krishna varathan\\Documents\\PDF_Spitting\\Data\\DT20234570014_Application_Form.pdf'
