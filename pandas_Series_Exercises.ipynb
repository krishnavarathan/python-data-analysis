# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnavarathan/python-data-analysis/blob/main/pandas_Series_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <hr style="border:5px solid #108999"> </hr>

# %% [markdown]
# # pandas Series <hr style="border:4.5px solid #108999"> </hr>

# %% [markdown]
# For starters, import the pandas library, using the relevant well-known convention.

# %%
import pandas as pd

# %% [markdown]
# ## .unique() & .nunique()

# %% [markdown]
# Load the "Region.csv" file and set the *squeeze* option to *True*. Store the information in a variable called **region_data**. Preview the data with the pandas *.head()* method.

# %%
region_data=pd.read_csv("/content/drive/MyDrive/Pandas_Exercises/Region.csv")
print(region_data.shape)
print(region_data.head())
# Out:
# (1042, 1)
#      Region
# 0  Region 2
# 1  Region 6
# 2  Region 3
# 3  Region 2
# 4  Region 3

# %% [markdown]
# Verify that **region_data** is a Series object.

# %%
rs=region_data.squeeze()
print(type(rs))
print(rs)
print(rs.shape)
print(rs.name)
# Out:
# <class 'pandas.core.series.Series'>
# 0       Region 2
# 1       Region 6
# 2       Region 3
# 3       Region 2
# 4       Region 3
#           ...
# 1037    Region 6
# 1038    Region 1
# 1039    Region 4
# 1040    Region 6
# 1041    Region 6
# Name: Region, Length: 1042, dtype: object
# (1042,)
# Region

# %% [markdown]
# Use the *.describe()* method to obtain descriptive statistics on the **region_data** Series.
# <br>Think of how many unique values there are in the data set.
# <br>*Please note that the statistics provided in the output exclude missing data.*

# %%
print(rs.describe())
# Out:
# count         1042
# unique          18
# top       Region 6
# freq           326
# Name: Region, dtype: object

# %% [markdown]
# You can obtain some of the values from the previous output by using Python built-in functions or methods. Please extract the total number of values from the **region_data** Series, then the number of unique values. Finally, obtain a list containing all unique values from this Series.

# %%
print("Total number of values: ",len(rs))
print("Unique values :", rs.unique())
uni_list=list(rs.unique())
uni_list
# Out:
# Total number of values:  1042
# Unique values : ['Region 2' 'Region 6' 'Region 3' 'Region 1' 'Region 5' 'Region 9'
#  'Region 7' 'Region 4' 'Region 12' 'Region 16' 'Region 8' 'Region 10'
#  'Region 13' 'Region 15' 'Region 11' 'Region 14' 'Region 17' 'Region 18']
# ['Region 2',
#  'Region 6',
#  'Region 3',
#  'Region 1',
#  'Region 5',
#  'Region 9',
#  'Region 7',
#  'Region 4',
#  'Region 12',
#  'Region 16',
#  'Region 8',
#  'Region 10',
#  'Region 13',
#  'Region 15',
#  'Region 11',
#  'Region 14',
#  'Region 17',
#  'Region 18']

# %% [markdown]
# ## .sort_values()

# %% [markdown]
# Load the "Region.csv" file and set the *squeeze* option to *True*. Store the information in a variable called **region_data**. Preview the data with the pandas *.head()* method.

# %%
region_data = pd.read_csv("/content/drive/MyDrive/Pandas_Exercises/Region.csv")
se=pd.Series(region_data.squeeze())
print(se.shape)
print(se)
print(se.head())
# Out:
# (1042,)
# 0       Region 2
# 1       Region 6
# 2       Region 3
# 3       Region 2
# 4       Region 3
#           ...
# 1037    Region 6
# 1038    Region 1
# 1039    Region 4
# 1040    Region 6
# 1041    Region 6
# Name: Region, Length: 1042, dtype: object
# 0    Region 2
# 1    Region 6
# 2    Region 3
# 3    Region 2
# 4    Region 3
# Name: Region, dtype: object

# %% [markdown]
# Sort the values without specifying any arguments.

# %% [markdown]
# *Please note that the numbers go from 1 to 18, but we are currently ordering the values as labels, not integers. 1 is succeeded by 10, then 11, and so on until 18. Then we have 2, 3, 4, etc., until 8, and eventually - 9.*

# %%
region_data.sort_values(by='Region')
# Out:
#        Region
# 462  Region 1
# 347  Region 1
# 609  Region 1
# 610  Region 1
# 339  Region 1
# ..        ...
# 536  Region 9
# 450  Region 9
# 8    Region 9
# 842  Region 9
# 940  Region 9
#
# [1042 rows x 1 columns]

# %% [markdown]
# Sort the values, setting the *ascending* parameter equal to *True*.

# %%
region_data.sort_values(ascending=True, by='Region')
# Out:
#        Region
# 462  Region 1
# 347  Region 1
# 609  Region 1
# 610  Region 1
# 339  Region 1
# ..        ...
# 536  Region 9
# 450  Region 9
# 8    Region 9
# 842  Region 9
# 940  Region 9
#
# [1042 rows x 1 columns]

# %% [markdown]
# Sort the values in **region_data** in descending order.

# %%
region_data.sort_values(ascending=False, by='Region')
# Out:
#        Region
# 450  Region 9
# 842  Region 9
# 141  Region 9
# 940  Region 9
# 8    Region 9
# ..        ...
# 569  Region 1
# 892  Region 1
# 558  Region 1
# 557  Region 1
# 309  Region 1
#
# [1042 rows x 1 columns]

# %% [markdown]
# ## Attribute and Method Chaining

# %% [markdown]
# Load the "Region.csv" file and set the *squeeze* option to *True*. Store the information in a variable called **region_data**. Preview the data with the pandas *.head()* method.

# %%
region_data = pd.read_csv("/content/drive/MyDrive/Pandas_Exercises/Region.csv")
region_data.sort_values(by='Region') # by is important argument while sorting the DataFrame column
AM=pd.Series(region_data.squeeze())
print(AM)
# Out:
# 0       Region 2
# 1       Region 6
# 2       Region 3
# 3       Region 2
# 4       Region 3
#           ...
# 1037    Region 6
# 1038    Region 1
# 1039    Region 4
# 1040    Region 6
# 1041    Region 6
# Name: Region, Length: 1042, dtype: object

# %% [markdown]
# Use method chaining to obtain the first five rows from the values of **region_data** sorted in ascending order.

# %%
ascen=AM.sort_values(ascending=True) # by is not-need an argument while sorting the Series column
ascen
# Out:
# 462    Region 1
# 347    Region 1
# 609    Region 1
# 610    Region 1
# 339    Region 1
#          ...
# 536    Region 9
# 450    Region 9
# 8      Region 9
# 842    Region 9
# 940    Region 9
# Name: Region, Length: 1042, dtype: object

# %% [markdown]
# Use method chaining to obtain the first five rows from the values of **region_data** sorted in descending order.

# %%
dscen=AM.sort_values(ascending=False)
dscen
# Out:
# 450    Region 9
# 842    Region 9
# 141    Region 9
# 940    Region 9
# 8      Region 9
#          ...
# 569    Region 1
# 892    Region 1
# 558    Region 1
# 557    Region 1
# 309    Region 1
# Name: Region, Length: 1042, dtype: object

# %% [markdown]
# Execute the next code cell to create a Series object called **emp_birth_date** that contains the employee numbers and the dates of birth of certain 4 employees.

# %%
emp_birth_date = pd.Series({'No_0001':'1963-08-02', 'No_0002':'1964-06-13', 'No_0003':'1989-12-04', 'No_0004':'1996-04-08'})
emp_birth_date
# Out:
# No_0001    1963-08-02
# No_0002    1964-06-13
# No_0003    1989-12-04
# No_0004    1996-04-08
# dtype: object

# %% [markdown]
# Obtain just the index of **emp_birth_date**.

# %%
print(emp_birth_date.index)
# Out:
# Index(['No_0001', 'No_0002', 'No_0003', 'No_0004'], dtype='object')

# %% [markdown]
# Obtain the row labels of the index, i.e. its values, stored in an array.

# %%
print(emp_birth_date.values)
# Out:
# ['1963-08-02' '1964-06-13' '1989-12-04' '1996-04-08']

# %% [markdown]
# ## .sort_index()

# %% [markdown]
# Load the "Region.csv" file and set the *squeeze* option to *True*. Store the information in a variable called **region_data**. Preview the data with the pandas *.head()* method.

# %%
region_data = pd.read_csv("/content/drive/MyDrive/Pandas_Exercises/Region.csv")
se_da=pd.Series(region_data.squeeze())
print(region_data.head())
print(type(region_data))
# Out:
#      Region
# 0  Region 2
# 1  Region 6
# 2  Region 3
# 3  Region 2
# 4  Region 3
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Overwrite the content of the **region_data** Series as you sort the values in *descending* order. Observe the index of the Series. Is it ordered correctly?

# %%
ascen=se_da.sort_values()
print(ascen)
# Out:
# 462    Region 1
# 347    Region 1
# 609    Region 1
# 610    Region 1
# 339    Region 1
#          ...
# 536    Region 9
# 450    Region 9
# 8      Region 9
# 842    Region 9
# 940    Region 9
# Name: Region, Length: 1042, dtype: object

# %% [markdown]
# Sort the index of the new version of the **region_data** Series object.

# %%
print(se_da.sort_index())
# Out:
# 0       Region 2
# 1       Region 6
# 2       Region 3
# 3       Region 2
# 4       Region 3
#           ...
# 1037    Region 6
# 1038    Region 1
# 1039    Region 4
# 1040    Region 6
# 1041    Region 6
# Name: Region, Length: 1042, dtype: object

# %% [markdown]
# Sort the index of the **region_data** Series in opposite direction. You can do that by setting the *ascending* parameter equal to *False*.

# %%
print(se_da.sort_index(ascending=False))
# Out:
# 1041    Region 6
# 1040    Region 6
# 1039    Region 4
# 1038    Region 1
# 1037    Region 6
#           ...
# 4       Region 3
# 3       Region 2
# 2       Region 3
# 1       Region 6
# 0       Region 2
# Name: Region, Length: 1042, dtype: object
